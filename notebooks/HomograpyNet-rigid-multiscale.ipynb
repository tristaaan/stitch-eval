# %% [markdown]
# # Deep Homography Net - rigid version

# %%
import glob
import pandas as pd
import numpy as np

import tensorflow as tf
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())

config = tf.ConfigProto()
# config.gpu_options.allocator_type = 'BFC'
tf.Session(config = config)
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 17776712565673099962
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 3152629760
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 2792461964980321117
# physical_device_desc: "device: 0, name: GeForce GTX 970, pci bus id: 0000:01:00.0, compute capability: 5.2"
# ]

# %% [markdown]
# ## Data Wrangling
#
# Read the directory

# %%
from os import path

train_split = 0.8
valid_split = 0.2

def load_img_paths(target):
    '''
    Retrieve the full path of all images in the dataset
    '''
    return glob.glob(target + '/*.tif')

data_dir = r'../data'
original_data_dir = path.join(data_dir, 'multiscale_512-1024')
all_files = pd.read_csv(path.join(original_data_dir, 'homographies.tsv'), sep='\t')
all_files.head()
# Out:
#    Unnamed: 0                    fname              h
# 0           0  Tp26_Y000_X000_040_0000  -0.078,-0.414
# 1           1  Tp26_Y000_X000_040_0001    0.363,0.076
# 2           2  Tp26_Y000_X000_040_0002    0.180,0.418
# 3           3  Tp26_Y000_X000_040_0003    0.434,0.086
# 4           4  Tp26_Y000_X000_040_0004   -0.128,0.178

# %%
all_files = all_files.sample(frac=1, random_state=123) # shuffle with seed 123 for reproducability
train_paths = []
valid_paths = []

if train_split <= 1:
    frac = int(all_files.shape[0] * train_split)
    train_paths = all_files[:frac].values.tolist()
    valid_paths = all_files[frac:].values.tolist()
else:
    valid_frac = int(train_split * valid_split)
    train_paths = all_files[:train_split].values.tolist()
    valid_paths = all_files[train_split:train_split+valid_frac].values.tolist()

assert(len(train_paths) > 0)
print('Traning images:    %d' % len(train_paths))
print('Validation images: %d' % len(valid_paths))
# Out:
# Traning images:    48000
# Validation images: 12000

# %%
import matplotlib.pylab as plt
# %matplotlib inline

def two_up(ref, mov):
    fig, (a, b) = plt.subplots(1, 2, figsize=(5, 8))
    a.imshow(ref, cmap='gray')
    a.set_title('Source')
    b.imshow(mov, cmap='gray')
    b.set_title('Target')
    plt.show()

def compare_all(ref, mov, pred):
    fig, (a, b, c) = plt.subplots(1, 3, figsize=(8, 8))
    a.imshow(ref, cmap='gray')
    a.set_title('Source')
    b.imshow(mov, cmap='gray')
    b.set_title('Target')
    c.imshow(pred, cmap='gray')
    c.set_title('Predicted')
    plt.show()
    
def compare_diff(ref,mov,pred):
    fig, (a, b, c) = plt.subplots(1, 3, figsize=(8, 8))
    a.imshow(ref, cmap='gray')
    a.set_title('Source')
    b.imshow(mov, cmap='gray')
    b.set_title('Target')
    c.imshow(abs(pred-mov), cmap='gray')
    c.set_title('Difference')
    plt.show()

from imageio import imread
tm1 = imread(original_data_dir + '/Tp26_Y000_X000_040_0015_A.tif')
tm2 = imread(original_data_dir + '/Tp26_Y000_X000_040_0015_B.tif')
two_up(tm1, tm2)

# %% [markdown]
# ## HomographyNet
#
# As the rigid version, we output two x,y parameters which represent the displacement

# %%
from keras.models import Sequential, Model
from keras.layers import BatchNormalization, Dense, Flatten, MaxPooling2D, Input, Activation, Dropout
from keras.layers.convolutional import Conv2D
import keras.backend as K

def euclidean_distance(y_true, y_pred):
    return K.sqrt(K.sum(K.square(y_pred - y_true), axis=-1, keepdims=True))

def conv_block(m, filters):
    kernel = (3, 3)
    m = Conv2D(filters, kernel, padding='same', activation='relu')(m)
    return BatchNormalization()(m)

def conv_group(m, filters):
    m = conv_block(m, filters)
    m = conv_block(m, filters)
    return MaxPooling2D(pool_size=(2, 2), strides=(2, 2))(m)

def homography_regression_model(input_dims):
    input_shape=(*input_dims, 2)
    
    input_layer = Input(shape=input_shape, name='input_layer')
    
    # 4x 64
    x = conv_group(input_layer, 64) # 1,2
    x = conv_group(x,           64) # 3,4
    # 4x 128
    x = conv_group(x,           128) # 1,2
    x = conv_block(x,           128) # 3
    x = conv_block(x,           128) # 4
    x = Flatten()(x)
    x = Dropout(0.5)(x)
    
    x = Dense(1024, name='FC_1024')(x)
    x = Dropout(0.5)(x)
    
    out = Dense(2, name='output')(x)
    
    return Model(inputs=input_layer, outputs=[out])

# %%
from keras.optimizers import SGD, Adam

img_size = tm1.shape[:2]

# opt = SGD(lr=0.005, momentum=0.9, decay=0.0015)
opt = SGD(lr=0.001, momentum=0.9, decay=0.0)
# opt = Adam(lr=0.005, beta_1=0.9, beta_2=0.999, epsilon=1e-08)

my_model = homography_regression_model(img_size)
my_model.compile(optimizer=opt, loss=euclidean_distance)
my_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_layer (InputLayer)     (None, 128, 128, 2)       0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 128, 128, 64)      1216
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 128, 128, 64)      256
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 128, 128, 64)      36928
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 128, 128, 64)      256
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 64, 64, 64)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 64, 64, 64)        36928
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 64, 64, 64)        256
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 64, 64, 64)        36928
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 64, 64, 64)        256
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 32, 32, 64)        0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 32, 32, 128)       73856
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 32, 32, 128)       512
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 32, 32, 128)       147584
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 32, 32, 128)       512
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 16, 16, 128)       147584
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 16, 16, 128)       512
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 16, 16, 128)       147584
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 16, 16, 128)       512
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 32768)             0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 32768)             0
# _________________________________________________________________
# FC_1024 (Dense)              (None, 1024)              33555456
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# output (Dense)               (None, 2)                 2050
# =================================================================
# Total params: 34,189,186
# Trainable params: 34,187,650
# Non-trainable params: 1,536
# _________________________________________________________________

# %% [markdown]
# ## Data Generators
#
# We generate the "seemingly infinite training data" on the fly by using Keras' DataGenerators.

# %%
import math
from os import path
from keras.callbacks import ModelCheckpoint, Callback, EarlyStopping, LearningRateScheduler
from keras.preprocessing.image import img_to_array, load_img
from keras.utils import Sequence
from skimage.transform import rotate


def h_string_to_arr(s):
    return np.array(list(map(lambda x: np.float32(x), s.split(','))))
    

class LossHistory(Callback):
    def on_train_begin(self, logs={}):
        self.losses = []
        self.val_losses = []

    def on_batch_end(self, batch, logs={}):
        self.losses.append(logs.get('loss'))
        self.val_losses.append(logs.get('val_loss'))
        
class DataGenerator(Sequence):
    '''
    Adapted from https://stanford.edu/~shervine/blog/keras-how-to-generate-data-on-the-fly.html
    Allows for multiprocessing in the fit generator
    '''

    def __init__(self, train_set, batch_size, im_size, train_dir):
        self.train = train_set
        self.batch_size = batch_size
        self.im_size = im_size
        self.train_dir = train_dir

    def __len__(self):
        return int(np.ceil(len(self.train) / float(self.batch_size)))

    def invert(self, im):
        return abs(255 - im)
    
    def read_images(self, fname):
        ext = '.tif'
        base = path.join(self.train_dir, fname)
        a = self.invert(img_to_array(load_img(base + '_A' + ext, grayscale=True)))
        b = self.invert(img_to_array(load_img(base + '_B' + ext, grayscale=True)))
        return np.dstack((a,b))
    
    # Will output sequence of tuples (image, test) given a datapath
    def __getitem__(self, idx):
        X = np.zeros(shape=(batch_size, self.im_size[0], self.im_size[1], 2))
        y = np.zeros(shape=(batch_size, 2))
        batch = self.train[idx * self.batch_size:(idx + 1) * self.batch_size]
        for j,row in enumerate(batch):
            fname, h_str = row[1:]
            X[j] = self.read_images(fname)
            y[j] = h_string_to_arr(h_str)
        return (X, y)

class AugmentedDataGenerator(DataGenerator):
    '''
    Same as DataGenerator but augments data by overriding `read_image`.
    '''

    def read_images(self, fname):
        '''
        reflection augmentations
        '''
        ext = '.tif'
        base = path.join(self.train_dir, fname)
        a = self.invert(img_to_array(load_img(base + '_A' + ext, grayscale=True)))
        b = self.invert(img_to_array(load_img(base + '_B' + ext, grayscale=True)))
        flip_dir = np.random.choice([None, 0, 1, 2])
        if flip_dir == None:
            return np.dstack((a,b))
        elif flip_dir < 2: # flip horizontal or vertical
            a = np.flip(a, flip_dir)
            b = np.flip(b, flip_dir)
        else: # flip_dir == 2, flip both directions
            a = np.flip(np.flip(a, 0),1)
            b = np.flip(np.flip(b, 0),1)
        return np.dstack((a,b))    
    
early_stopping = EarlyStopping(monitor='val_loss', patience=12, verbose=1, mode='auto')

# create weights file if it doesn't exist for ModelCheckpoint
from os import mkdir
try: 
    mkdir('tmp')
except FileExistsError:
    print('tmp directory already exists')

history = LossHistory()

def step_scheduler(epoch, lr):
    step = int(epochs/3)
    if epoch % step == 0 and epoch > 0: # if this is a step epoch:
        new_lr = lr * 0.5 # decrease lr by some factor
        print('learning rate decreased from %f to %f' % (lr, new_lr))
        return new_lr   
    return lr # no change

lrScheduler = LearningRateScheduler(step_scheduler)
# Out:
# tmp directory already exists

# %% [markdown]
# ## Training
#
# > We use a base learning rate of 0.005 and decrease the learning rate by a factor of 10 after every 30,000 iterations.The networks are trained for for 90,000 total iterations using a batch size of 64.

# %%
from datetime import date

batch_size = 32
total_iterations = 60000

steps_per_epoch  = int(len(train_paths) / batch_size)
validation_steps = int(len(valid_paths) / batch_size)

epochs = int(total_iterations / steps_per_epoch)

training_generator   = DataGenerator(train_paths, batch_size, img_size, original_data_dir)
validation_generator = DataGenerator(valid_paths, batch_size, img_size, original_data_dir)

# descriptive weight file naming
out_name = 'multiscale-hnet-weights-%d-%d-40k-%s' % \
           (batch_size, img_size[0], date.today().isoformat())
checkpointer = ModelCheckpoint(filepath='tmp/%s.hdf5' % out_name, 
                               verbose=1, save_best_only=True)

print('Epochs:            %d' % epochs)
print('Traning images:    %d' % len(train_paths))
print('Validation images: %d' % len(valid_paths))
print('Training steps:    %d' % steps_per_epoch)
print('Validation steps:  %d' % validation_steps)
# Out:
# Epochs:            40
# Traning images:    48000
# Validation images: 12000
# Training steps:    1500
# Validation steps:  375

# %%
hist = my_model.fit_generator(training_generator,
                              validation_data=validation_generator,
                              epochs=epochs,
                              workers=3,
                              verbose=2,
                              callbacks=[history, checkpointer, early_stopping, lrScheduler]
                             )
# Out:
# Epoch 1/40
#  - 262s - loss: 1.3282 - val_loss: 0.5839
#
# Epoch 00001: val_loss improved from inf to 0.58388, saving model to tmp/multiscale-hnet-weights-32-128-40k-2019-05-17.hdf5
# Epoch 2/40
#  - 262s - loss: 0.8564 - val_loss: 0.4490
#
# Epoch 00002: val_loss improved from 0.58388 to 0.44899, saving model to tmp/multiscale-hnet-weights-32-128-40k-2019-05-17.hdf5
# Epoch 3/40
#  - 262s - loss: 0.6342 - val_loss: 0.3834
#
# Epoch 00003: val_loss improved from 0.44899 to 0.38340, saving model to tmp/multiscale-hnet-weights-32-128-40k-2019-05-17.hdf5
# Epoch 4/40
#  - 262s - loss: 0.4960 - val_loss: 0.2864
#
# Epoch 00004: val_loss improved from 0.38340 to 0.28636, saving model to tmp/multiscale-hnet-weights-32-128-40k-2019-05-17.hdf5
# Epoch 5/40
#  - 261s - loss: 0.4340 - val_loss: 0.3609
#
# Epoch 00005: val_loss did not improve from 0.28636
# Epoch 6/40
#  - 261s - loss: 0.3918 - val_loss: 0.4865
#
# Epoch 00006: val_loss did not improve from 0.28636
# Epoch 7/40
#  - 262s - loss: 0.3190 - val_loss: 0.6566
#
# Epoch 00007: val_loss did not improve from 0.28636
# Epoch 8/40
#  - 262s - loss: 0.2403 - val_loss: 0.4001
#
# Epoch 00008: val_loss did not improve from 0.28636
# Epoch 9/40
#  - 262s - loss: 0.1895 - val_loss: 0.1004
#
# Epoch 00009: val_loss improved from 0.28636 to 0.10044, saving model to tmp/multiscale-hnet-weights-32-128-40k-2019-05-17.hdf5
# Epoch 10/40
#  - 262s - loss: 0.1563 - val_loss: 0.1151
#
# Epoch 00010: val_loss did not improve from 0.10044
# Epoch 11/40
#  - 262s - loss: 0.1309 - val_loss: 0.0999
#
# Epoch 00011: val_loss improved from 0.10044 to 0.09990, saving model to tmp/multiscale-hnet-weights-32-128-40k-2019-05-17.hdf5
# Epoch 12/40
#  - 262s - loss: 0.1155 - val_loss: 0.0970
#
# Epoch 00012: val_loss improved from 0.09990 to 0.09696, saving model to tmp/multiscale-hnet-weights-32-128-40k-2019-05-17.hdf5
# Epoch 13/40
#  - 262s - loss: 0.1046 - val_loss: 0.0867
#
# Epoch 00013: val_loss improved from 0.09696 to 0.08675, saving model to tmp/multiscale-hnet-weights-32-128-40k-2019-05-17.hdf5
# Epoch 14/40
# learning rate decreased from 0.001000 to 0.000500
#  - 262s - loss: 0.0931 - val_loss: 0.0792
#
# Epoch 00014: val_loss improved from 0.08675 to 0.07919, saving model to tmp/multiscale-hnet-weights-32-128-40k-2019-05-17.hdf5
# Epoch 15/40
#  - 262s - loss: 0.0891 - val_loss: 0.0767
#
# Epoch 00015: val_loss improved from 0.07919 to 0.07672, saving model to tmp/multiscale-hnet-weights-32-128-40k-2019-05-17.hdf5
# Epoch 16/40
#  - 262s - loss: 0.0868 - val_loss: 0.0745
#
# Epoch 00016: val_loss improved from 0.07672 to 0.07446, saving model to tmp/multiscale-hnet-weights-32-128-40k-2019-05-17.hdf5
# Epoch 17/40
#  - 262s - loss: 0.0846 - val_loss: 0.0752
#
# Epoch 00017: val_loss did not improve from 0.07446
# Epoch 18/40
#  - 262s - loss: 0.0823 - val_loss: 0.0731
#
# Epoch 00018: val_loss improved from 0.07446 to 0.07315, saving model to tmp/multiscale-hnet-weights-32-128-40k-2019-05-17.hdf5
# Epoch 19/40
#  - 262s - loss: 0.0810 - val_loss: 0.0689
#
# Epoch 00019: val_loss improved from 0.07315 to 0.06891, saving model to tmp/multiscale-hnet-weights-32-128-40k-2019-05-17.hdf5
# Epoch 20/40
#  - 262s - loss: 0.0792 - val_loss: 0.0722
#
# Epoch 00020: val_loss did not improve from 0.06891
# Epoch 21/40
#  - 262s - loss: 0.0778 - val_loss: 0.0658
#
# Epoch 00021: val_loss improved from 0.06891 to 0.06577, saving model to tmp/multiscale-hnet-weights-32-128-40k-2019-05-17.hdf5
# Epoch 22/40
#  - 262s - loss: 0.0759 - val_loss: 0.0650
#
# Epoch 00022: val_loss improved from 0.06577 to 0.06504, saving model to tmp/multiscale-hnet-weights-32-128-40k-2019-05-17.hdf5
# Epoch 23/40
#  - 262s - loss: 0.0748 - val_loss: 0.0688
#
# Epoch 00023: val_loss did not improve from 0.06504
# Epoch 24/40
#  - 262s - loss: 0.0733 - val_loss: 0.0644
#
# Epoch 00024: val_loss improved from 0.06504 to 0.06442, saving model to tmp/multiscale-hnet-weights-32-128-40k-2019-05-17.hdf5
# Epoch 25/40
#  - 262s - loss: 0.0721 - val_loss: 0.0634
#
# Epoch 00025: val_loss improved from 0.06442 to 0.06341, saving model to tmp/multiscale-hnet-weights-32-128-40k-2019-05-17.hdf5
# Epoch 26/40
#  - 262s - loss: 0.0713 - val_loss: 0.0621
#
# Epoch 00026: val_loss improved from 0.06341 to 0.06210, saving model to tmp/multiscale-hnet-weights-32-128-40k-2019-05-17.hdf5
# Epoch 27/40
# learning rate decreased from 0.000500 to 0.000250
#  - 262s - loss: 0.0692 - val_loss: 0.0588
#
# Epoch 00027: val_loss improved from 0.06210 to 0.05878, saving model to tmp/multiscale-hnet-weights-32-128-40k-2019-05-17.hdf5
# Epoch 28/40
#  - 262s - loss: 0.0683 - val_loss: 0.0590
#
# Epoch 00028: val_loss did not improve from 0.05878
# Epoch 29/40
#  - 262s - loss: 0.0678 - val_loss: 0.0593
#
# Epoch 00029: val_loss did not improve from 0.05878
# Epoch 30/40
#  - 262s - loss: 0.0674 - val_loss: 0.0590
#
# Epoch 00030: val_loss did not improve from 0.05878
# Epoch 31/40
#  - 262s - loss: 0.0671 - val_loss: 0.0582
#
# Epoch 00031: val_loss improved from 0.05878 to 0.05821, saving model to tmp/multiscale-hnet-weights-32-128-40k-2019-05-17.hdf5
# Epoch 32/40
#  - 263s - loss: 0.0667 - val_loss: 0.0592
#
# Epoch 00032: val_loss did not improve from 0.05821
# Epoch 33/40
#  - 263s - loss: 0.0663 - val_loss: 0.0586
#
# Epoch 00033: val_loss did not improve from 0.05821
# Epoch 34/40
#  - 263s - loss: 0.0660 - val_loss: 0.0582
#
# Epoch 00034: val_loss did not improve from 0.05821
# Epoch 35/40
#  - 263s - loss: 0.0657 - val_loss: 0.0572
#
# Epoch 00035: val_loss improved from 0.05821 to 0.05717, saving model to tmp/multiscale-hnet-weights-32-128-40k-2019-05-17.hdf5
# Epoch 36/40
#  - 263s - loss: 0.0651 - val_loss: 0.0559
#
# Epoch 00036: val_loss improved from 0.05717 to 0.05593, saving model to tmp/multiscale-hnet-weights-32-128-40k-2019-05-17.hdf5
# Epoch 37/40
#  - 263s - loss: 0.0649 - val_loss: 0.0559
#
# Epoch 00037: val_loss improved from 0.05593 to 0.05589, saving model to tmp/multiscale-hnet-weights-32-128-40k-2019-05-17.hdf5
# Epoch 38/40
#  - 263s - loss: 0.0647 - val_loss: 0.0553
#
# Epoch 00038: val_loss improved from 0.05589 to 0.05531, saving model to tmp/multiscale-hnet-weights-32-128-40k-2019-05-17.hdf5
# Epoch 39/40
#  - 262s - loss: 0.0642 - val_loss: 0.0548
#
# Epoch 00039: val_loss improved from 0.05531 to 0.05481, saving model to tmp/multiscale-hnet-weights-32-128-40k-2019-05-17.hdf5
# Epoch 40/40
# learning rate decreased from 0.000250 to 0.000125
#  - 262s - loss: 0.0635 - val_loss: 0.0544
#
# Epoch 00040: val_loss improved from 0.05481 to 0.05439, saving model to tmp/multiscale-hnet-weights-32-128-40k-2019-05-17.hdf5

# %% [markdown]
# ## Results inspection

# %%
import json

with open('tmp/%s.json' % out_name, 'w') as fh:
    fh.write(json.dumps(hist.history))

plt.figure(figsize=(12,8))
plt.plot(hist.epoch,hist.history['loss'],    label='Train')
plt.plot(hist.epoch,hist.history['val_loss'],label='Validation',linestyle='--')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
# load model if needed
my_model = homography_regression_model(img_size)
my_model.compile(optimizer=opt, loss=euclidean_distance)
my_model.load_weights('tmp/rigid-hnet-weights-16-128-40k-1drop-2019-05-13.hdf5')

# %%
import cv2
from numpy.random import randint
from skimage.transform import resize

def alter_pt_constant(pt,x,y):
    return (pt[0] + x, pt[1] + y)

def create_multiscale_rigid_patches(im, w_min, w_max, final_size, max_overlap):
    '''
    Create pairs of patches from an image
    '''
    size = randint(w_min, w_max)
    r = int(max_overlap * size)
    im = np.pad(im, int(2*r), mode='constant', constant_values=np.median(im))
    while True:
        # generate two random points, r to size-r so as to not go over the edge
        x = randint(2*r, im.shape[1]-size-2*r)
        y = randint(2*r, im.shape[0]-size-2*r)

        A = im[y:y+size,x:x+size] # this is our 'reference' image
        A = cv2.resize(A, final_size, interpolation=cv2.INTER_CUBIC)
        
        # generate x,y displacements
        x_dis, y_dis = randint(-r, r+1, 2)
        
        B = im[y+y_dis:y+size+y_dis, 
               x+x_dis:x+size+x_dis]
        B = cv2.resize(B, final_size, interpolation=cv2.INTER_CUBIC)
        
        # make sure the images actually have contents.
        thresh = 750
        _, binary_a = cv2.threshold(A,127,1,cv2.THRESH_BINARY_INV)
        _, binary_b = cv2.threshold(B,127,1,cv2.THRESH_BINARY_INV)
        if A.shape == B.shape and binary_a.sum() > thresh and binary_b.sum() > thresh:
            scaled_dis = [ x_dis / size, y_dis / size]
            return A, B, scaled_dis 
        
import sys
sys.path.insert(0, '../src')
from util import pad,merge
    
def invert(im):
    return abs(255 - im)
    
test_dir = r'../data/learning'
im1 = imread(test_dir + '/Tp26_Y003_X003_040.tif')
# im1 = cv2.resize(im1, (672,512), interpolation=cv2.INTER_NEAREST)

p_a, p_b, H_act = create_multiscale_rigid_patches(im1, 512, 1024, img_size, 0.5)
H_act = np.array(H_act) * img_size[0]
p_a = cv2.resize(p_a, img_size, interpolation=cv2.INTER_NEAREST)
p_b = cv2.resize(p_b, img_size, interpolation=cv2.INTER_NEAREST)

test_im = np.dstack((invert(p_a), invert(p_b)))
test_im = test_im.reshape(1, *test_im.shape)

H_2pt = my_model.predict(test_im)[0]

# H_2pt[0] *= (np.sign(H_2pt[0]) - H_2pt[0]) * img_size[0]
# H_2pt[1] *= (np.sign(H_2pt[1]) - H_2pt[1]) * img_size[0]

H_2pt[0] *=  img_size[0]
H_2pt[1] *=  img_size[0]

predicted = merge(p_a, p_b, H_2pt[0], H_2pt[1])
# predicted = merge(p_a, p_b, H_act[0], H_act[1])

print(H_act, '\n\n', H_2pt)
compare_all(p_a, p_b, predicted)
# Out:
# [ 25.66799469 -58.30544489]
#
#  [ 26.327723 -54.792908]

# %%
test_dir = r'../data/learning'

p = 320
im1 = cv2.imread(test_dir + '/Tp26_Y003_X006_040.tif', cv2.IMREAD_UNCHANGED)[:1024, 256:]
# im1 = np.pad(im1, (0,p), mode='constant', constant_values=np.median(im1))
print(im1.shape)
im1 = cv2.resize(im1, img_size, interpolation=cv2.INTER_CUBIC)

im2 = cv2.imread(test_dir + '/Tp26_Y003_X007_040.tif', cv2.IMREAD_UNCHANGED)[:1024, :1024]
# im2 = np.pad(im2, (0,p), mode='constant', constant_values=np.median(im2))
im2 = cv2.resize(im2, img_size, interpolation=cv2.INTER_CUBIC)

test_im = np.dstack((invert(im1), invert(im2)))
test_im = test_im.reshape(1, *test_im.shape)
H_2pt = my_model.predict(test_im)[0]
# predicted = pad(im1, *H_2pt[0])

H_2pt[0] *= img_size[0] * -1
H_2pt[1] *= img_size[0] * -1

predicted = merge(im1, im2, H_2pt[0], H_2pt[1])

print(H_2pt)
compare_all(im1, im2, predicted)
# Out:
# (1024, 1088)
# [35.54175     0.13684839]
